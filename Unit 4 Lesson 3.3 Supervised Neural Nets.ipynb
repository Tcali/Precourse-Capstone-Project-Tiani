# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
artworks = pd.read_csv('https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv')

# %%
# Select Columns.
artworks = artworks[['Artist', 'Nationality', 'Gender', 'Date', 'Department',
                    'DateAcquired', 'URL', 'ThumbnailURL', 'Height (cm)', 'Width (cm)']]

# Convert URL's to booleans.
artworks['URL'] = artworks['URL'].notnull()
artworks['ThumbnailURL'] = artworks['ThumbnailURL'].notnull()

# Drop films and some other tricky rows.
artworks = artworks[artworks['Department']!='Film']
artworks = artworks[artworks['Department']!='Media and Performance Art']
artworks = artworks[artworks['Department']!='Fluxus Collection']

# Drop missing data.
artworks = artworks.dropna()

# %%
artworks['DateAcquired'] = pd.to_datetime(artworks.DateAcquired)
artworks['YearAcquired'] = artworks.DateAcquired.dt.year

# %%
# Remove multiple nationalities, genders, and artists.
artworks.loc[artworks['Gender'].str.contains('\) \('), 'Gender'] = '\(multiple_persons\)'
artworks.loc[artworks['Nationality'].str.contains('\) \('), 'Nationality'] = '\(multiple_nationalities\)'
artworks.loc[artworks['Artist'].str.contains(','), 'Artist'] = 'Multiple_Artists'

# Convert dates to start date, cutting down number of distinct examples.
artworks['Date'] = pd.Series(artworks.Date.str.extract(
    '([0-9]{4})', expand=False))[:-1]

# Final column drops and NA drop.
X = artworks.drop(['Department', 'DateAcquired', 'Artist', 'Nationality', 'Date'], 1)

# %%
counts = artworks['Artist'].value_counts()
artworks_filt = artworks.groupby('Artist', as_index=False).size().reset_index(name='counts')
artworks_filt = artworks_filt.sort_values(['counts'], ascending=False)
happy_artists = artworks_filt['Artist'].values.tolist()[0:99]
artworks_small = artworks[artworks['Artist'].isin(happy_artists)]
artworks_small
# Out:
#                           Artist                 Nationality  \
# 65              Multiple_Artists  \(multiple_nationalities\)
# 66              Multiple_Artists  \(multiple_nationalities\)
# 76              Multiple_Artists  \(multiple_nationalities\)
# 107             Multiple_Artists  \(multiple_nationalities\)
# 110             Multiple_Artists  \(multiple_nationalities\)
# 111             Multiple_Artists  \(multiple_nationalities\)
# 112             Multiple_Artists  \(multiple_nationalities\)
# 113             Multiple_Artists  \(multiple_nationalities\)
# 151             Multiple_Artists  \(multiple_nationalities\)
# 154             Multiple_Artists  \(multiple_nationalities\)
# 160             Multiple_Artists  \(multiple_nationalities\)
# 161             Multiple_Artists  \(multiple_nationalities\)
# 162             Multiple_Artists  \(multiple_nationalities\)
# 163             Multiple_Artists  \(multiple_nationalities\)
# ...

# %%
# Create dummies separately.
# artists = pd.get_dummies(artworks.Artist)
nationalities = pd.get_dummies(artworks_small.Nationality)
dates = pd.get_dummies(artworks_small.Date)

# Concat with other variables, but artists slows this wayyyyy down so we'll keep it out for now
X = pd.get_dummies(X, sparse=True)
X = pd.concat([X, nationalities, dates], axis=1)

Y = artworks_small.Department
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-57-4f10a4217722> in <module>()
#       6 # Concat with other variables, but artists slows this wayyyyy down so we'll keep it out for now
#       7 X = pd.get_dummies(X, sparse=True)
# ----> 8 X = pd.concat([X, nationalities, dates], axis=1)
#       9
#      10 Y = artworks_small.Department
#
# c:\users\tiani\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     211                        verify_integrity=verify_integrity,
#     212                        copy=copy)
# --> 213     return op.get_result()
#     214
#     215
#
# c:\users\tiani\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
# ...

# %%
# Import the model.
from sklearn.neural_network import MLPClassifier

# Establish and fit the model, with a single, 1000 perceptron layer.
mlp = MLPClassifier(hidden_layer_sizes=(10,1))
mlp.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-56-1b30343da09e> in <module>()
#       4 # Establish and fit the model, with a single, 1000 perceptron layer.
#       5 mlp = MLPClassifier(hidden_layer_sizes=(10,1))
# ----> 6 mlp.fit(X, Y)
#
# c:\users\tiani\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     971         """
#     972         return self._fit(X, y, incremental=(self.warm_start and
# --> 973                                             hasattr(self, "classes_")))
#     974
#     975     @property
#
# c:\users\tiani\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     376         if self.solver in _STOCHASTIC_SOLVERS:
# ...
