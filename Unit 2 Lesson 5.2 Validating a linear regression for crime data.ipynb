# %% [markdown]
# # General Comments about the data set
# This table provides the volume of violent crime (murder and nonnegligent manslaughter, rape, robbery, and aggravated assault) and property crime (burglary, larceny-theft, and motor vehicle theft) as reported by city and town law enforcement agencies (listed alphabetically by state) that contributed data to the UCR Program. (Note:  Arson is not included in the property crime total in this table; however, if complete arson data were provided, they will appear in the arson column.)
#
# Population estimation
# For the 2013 population estimates used in this table, the FBI computed individual rates of growth from one year to the next for every city/town and county using 2010 decennial population counts and 2011 through 2012 population estimates from the U.S. Census Bureau. Each agency’s rates of growth were averaged; that average was then applied and added to its 2012 Census population estimate to derive the agency’s 2013 population estimate.

# %% [markdown]
# # Instructions
#
# We'll use the property crime model you've been working on with, based on the FBI:UCR data. Since your model formulation to date has used the entire New York State 2013 dataset, you'll need to validate it using some of the other crime datasets available at the FBI:UCR website. Options include other states crime rates in 2013 or crime rates in New York State in other years or a combination of these.
# __I chose to test the model that I trained on NY to predict what will happen in CA, and see if the model is a good fit for the new data set__
#
# Iterate
# Based on the results of your validation test, create a revised model, and then test both old and new models on a new holdout or set of folds.
#
# Include your model(s) and a brief writeup of the reasoning behind the validation method you chose and the changes you made to submit and review with your mentor.

# %%
# import all the modules I need
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('mode.chained_assignment', None)
# %matplotlib inline
import seaborn as sns
import math


# import in the data table I downloaded from UCR
df = pd.DataFrame()
df = pd.read_excel(
    "table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls", sheet_name='13tbl8ny')

# %% [markdown]
# Need to clean by:
# - fixing headers (line 3) and deleting rows 0-2
# - dropping Rape\n(revised\ndefinition)1 column
# - filling in NaN with 0
#
#
# Need to create features by:
# - changing categorical variables to 0 and 1

# %%
df.drop([0, 1, 2], inplace=True)

# %%
df.drop('Unnamed: 4', axis=1, inplace=True)

# %%
df.columns = df.loc[3].values

# %%
df.drop([3, 352, 353, 354], inplace=True)

# %%
df['Arson3'] = df['Arson3'].fillna(0)
df
# Out:
#                            City Population Violent\ncrime  \
# 4                 Adams Village       1861              0
# 5      Addison Town and Village       2577              3
# 6                 Akron Village       2846              3
# 7                        Albany      97956            791
# 8                Albion Village       6388             23
# 9                Alfred Village       4089              5
# 10             Allegany Village       1781              3
# 11                 Amherst Town     118296            107
# 12           Amityville Village       9519              9
# 13                    Amsterdam      18182             30
# 14               Arcade Village       2053              0
# 15              Ardsley Village       4523              5
# 16            Asharoken Village        658              0
# 17               Attica Village       2522              2
# 18                       Auburn      27270             96
# 19                 Avon Village       3333              1
# 20        Baldwinsville Village       7473              5
# 21         Ballston Spa Village       5418              8
# 22                      Batavia      15374             57
# 23                 Bath Village       5733             15
# 24                 Bedford Town      17627              5
# 25               Bethlehem Town      34243             13
# 26                   Binghamton      46304            284
# 27                  Black River       1410              0
# 28          Blooming Grove Town      12001              8
# 29              Bolivar Village       1022              1
# 30                  Bolton Town       2325              2
# 31            Boonville Village       2054              1
# 32                   Brant Town       2065              4
# 33                     Brewster       2358              0
# ..                          ...        ...            ...
# 322         Tupper Lake Village       3642              3
# 323         Tuxedo Park Village        615              0
# 324                 Ulster Town      12195             14
# 325                       Utica      61686            361
# 326                 Vestal Town      27980             16
# 327              Walden Village       6887             18
# 328               Wallkill Town      27940             40
# 329              Walton Village       3012              6
# 330              Warsaw Village       3453              6
# 331     Washingtonville Village       5828              2
# 332  Waterford Town and Village       8392              4
# 333            Waterloo Village       5175             11
# 334                   Watertown      28179            109
# 335                  Watervliet      10245             26
# 336        Watkins Glen Village       1862              6
# 337             Waverly Village       4337              5
# 338    Webster Town and Village      43777             21
# 339           Weedsport Village       1797              0
# 340          Wellsville Village       4574             11
# 341   Westhampton Beach Village       1732              2
# 342            West Seneca Town      44821             35
# 343           Whitehall Village       2604              6
# 344                White Plains      57559             78
# 345          Whitesboro Village       3733              4
# 346             Whitestown Town       9141              0
# 347               Woodbury Town      10685              3
# 348           Woodridge Village        829              7
# 349              Woodstock Town       5931              2
# 350                     Yonkers     199134           1036
# 351               Yorktown Town      36643             15
#
#     Murder and\nnonnegligent\nmanslaughter Rape\n(legacy\ndefinition)2  \
# 4                                        0                           0
# 5                                        0                           0
# 6                                        0                           0
# 7                                        8                          30
# 8                                        0                           3
# 9                                        0                           0
# 10                                       0                           0
# 11                                       1                           7
# 12                                       0                           2
# 13                                       0                           0
# 14                                       0                           0
# 15                                       0                           0
# 16                                       0                           0
# 17                                       0                           0
# 18                                       1                          20
# 19                                       0                           0
# 20                                       0                           0
# 21                                       0                           0
# 22                                       0                           7
# 23                                       0                           1
# 24                                       0                           0
# 25                                       0                           0
# 26                                       3                          19
# 27                                       0                           0
# 28                                       0                           1
# 29                                       0                           0
# 30                                       0                           0
# 31                                       0                           0
# 32                                       0                           0
# 33                                       0                           0
# ..                                     ...                         ...
# 322                                      0                           0
# 323                                      0                           0
# 324                                      0                           3
# 325                                      7                          27
# 326                                      0                           2
# 327                                      1                           2
# 328                                      0                           3
# 329                                      0                           1
# 330                                      0                           1
# 331                                      0                           0
# 332                                      0                           0
# 333                                      0                           0
# 334                                      0                          12
# 335                                      1                           3
# 336                                      0                           0
# 337                                      0                           0
# 338                                      0                           2
# 339                                      0                           0
# 340                                      0                           1
# 341                                      0                           0
# 342                                      1                           1
# 343                                      0                           0
# 344                                      1                           3
# 345                                      0                           0
# 346                                      0                           0
# 347                                      0                           0
# 348                                      0                           0
# 349                                      0                           0
# 350                                      6                          25
# 351                                      0                           0
#
#     Robbery Aggravated\nassault Property\ncrime Burglary Larceny-\ntheft  \
# 4         0                   0              12        2              10
# 5         0                   3              24        3              20
# 6         0                   3              16        1              15
# 7       227                 526            4090      705            3243
# 8         4                  16             223       53             165
# 9         3                   2              46       10              36
# 10        0                   3              10        0              10
# 11       31                  68            2118      204            1882
# 12        4                   3             210       16             188
# 13       12                  18             405       99             291
# 14        0                   0              39        3              35
# 15        3                   2              33        4              28
# 16        0                   0               2        0               2
# 17        0                   2               5        0               4
# 18       22                  53             859      132             721
# 19        1                   0              25        3              20
# 20        1                   4              88       10              77
# 21        3                   5              94       16              78
# 22       13                  37             559      103             454
# 23        3                  11             191       32             157
# 24        1                   4             156       26             127
# 25        3                  10             442       50             388
# 26      101                 161            2349      525            1767
# 27        0                   0              14        2              12
# 28        0                   7              99       20              72
# 29        0                   1               4        2               2
# 30        0                   2              24        4              20
# 31        0                   1              20        6              14
# 32        1                   3              31        9              20
# 33        0                   0              13        3              10
# ..      ...                 ...             ...      ...             ...
# 322       0                   3              83       22              59
# 323       0                   0               0        0               0
# 324       2                   9             437       25             410
# 325     102                 225            2528      449            1997
# 326       6                   8             571       39             523
# 327       1                  14             142       13             124
# 328      16                  21             767       91             650
# 329       0                   5              68       18              50
# 330       0                   5              78        5              73
# 331       1                   1              58        5              51
# 332       0                   4              59        6              52
# 333       3                   8             194       23             169
# 334      16                  81            1165      169             953
# 335      11                  11             242       58             163
# 336       0                   6              92       10              80
# 337       1                   4              54        9              41
# 338       3                  16             469      101             361
# 339       0                   0              25        5              20
# 340       0                  10             164       32             129
# 341       0                   2              44        4              37
# 342       9                  24             896      166             710
# 343       0                   6              62       12              49
# 344      28                  46            1232       77            1134
# 345       0                   4              36       14              21
# 346       0                   0              77       13              61
# 347       2                   1             541        9             529
# 348       0                   7              17        8               9
# 349       0                   2              58       13              45
# 350     390                 615            2368      470            1662
# 351       2                  13             334       45             287
#
#     Motor\nvehicle\ntheft  Arson3
# 4                       0       0
# 5                       1       0
# 6                       0       0
# 7                     142       0
# 8                       5       0
# 9                       0       0
# 10                      0       0
# 11                     32       3
# 12                      6       1
# 13                     15       0
# 14                      1       0
# 15                      1       0
# 16                      0       0
# 17                      1       0
# 18                      6       0
# 19                      2       0
# 20                      1       0
# 21                      0       1
# 22                      2       0
# 23                      2       2
# 24                      3       0
# 25                      4       0
# 26                     57       0
# 27                      0       0
# 28                      7       0
# 29                      0       0
# 30                      0       0
# 31                      0       0
# 32                      2       0
# 33                      0       0
# ..                    ...     ...
# 322                     2       0
# 323                     0       0
# 324                     2       0
# 325                    82       0
# 326                     9       0
# 327                     5       0
# 328                    26       1
# 329                     0       0
# 330                     0       0
# 331                     2       0
# 332                     1       0
# 333                     2       0
# 334                    43       0
# 335                    21       0
# 336                     2       0
# 337                     4       0
# 338                     7       0
# 339                     0       0
# 340                     3       1
# 341                     3       0
# 342                    20       0
# 343                     1       0
# 344                    21       0
# 345                     1       0
# 346                     3       0
# 347                     3       0
# 348                     0       0
# 349                     0       0
# 350                   236      10
# 351                     2       0
#
# [348 rows x 12 columns]

# %%
df['Population'] = df['Population'].astype(int)
df['Population2'] = df['Population']**2

# %%
df['Robbery'] = df['Robbery'].astype(int)
df['Robbery'] = df['Robbery'].apply(lambda x: (x > 0)*1)

# %%
df['Murder and\nnonnegligent\nmanslaughter'] = df['Murder and\nnonnegligent\nmanslaughter'].astype(
    int)
df['Murder and\nnonnegligent\nmanslaughter'] = df['Murder and\nnonnegligent\nmanslaughter'].apply(
    lambda x: (x > 0)*1)

# %%
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

# Suppress annoying harmless error.
import warnings
warnings.filterwarnings(action="ignore", module="scipy",
                        message="^internal gelsd")

# %%
regr = linear_model.LinearRegression()
regr.fit(df[['Population', 'Population2',
             'Murder and\nnonnegligent\nmanslaughter', 'Robbery']], df['Property\ncrime'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.coef_
# Out:
# array([ 1.69008467e-02, -1.73980871e-07,  6.15497194e+02,  1.48320688e+02])

# %%
regr.score(df[['Population', 'Population2',
               'Murder and\nnonnegligent\nmanslaughter', 'Robbery']], df['Property\ncrime'])
# Out:
# 0.9935839631191373

# %% [markdown]
# Predictions. First figuring out how many property crimes there would be in Davis with the specification we had earlier.
#
# With Drew, we realized how important it was for population to be in the regression specification. When we took out population, the regr score went way down. We see how adding random noise increases the regr score by overfitting the data.

# %%
# predicting the nuber of property crimes in Davis:
regr.predict([[68111, 68111**2, 0, 0]])
# Out:
# array([318.62882533])

# %%
regr = linear_model.LinearRegression()
regr.fit(df[['Population2', 'Murder and\nnonnegligent\nmanslaughter',
             'Robbery']], df['Property\ncrime'])
regr.score(df[['Population2', 'Murder and\nnonnegligent\nmanslaughter',
               'Robbery']], df['Property\ncrime'])
# Out:
# 0.05208377602595937

# %%
regr = linear_model.LinearRegression()
X = df[['Population2', 'Murder and\nnonnegligent\nmanslaughter', 'Robbery']].values
N = np.random.randn(X.shape[0], 10)
X = np.concatenate((X, N), axis=1)
regr.fit(X, df['Property\ncrime'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.score(X, df['Property\ncrime'])
# Out:
# 0.07300583209075984

# %% [markdown]
# Now, let's use the new linear regression code that I learned in this lesson to refit the model and check params, pvalues, and the rsquared value for NY

# %%
import statsmodels.formula.api as smf
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
#rename and change the data type to be numerical instead of an object
df['Property\ncrime'] = df['Property\ncrime'].astype(int)
df['Population2'] = df['Population2'].astype(int)
df['Property_crime'] = df['Property\ncrime']
df['Murder'] = df['Murder and\nnonnegligent\nmanslaughter']

# %%
# Re-fit the model here.
linear_formula = 'Property_crime ~ Population + Murder'

# Fit the model to our data using the formula.
lm = smf.ols(formula=linear_formula, data=df).fit()
print(lm.params)
print(lm.pvalues)
print(lm.rsquared)
print(lm.conf_int())
# Out:
# Intercept     24.873
# Population     0.017
# Murder       654.243
# dtype: float64
# Intercept    0.491
# Population   0.000
# Murder       0.000
# dtype: float64
# 0.9934062182812436
#                  0       1
# Intercept  -46.097  95.844
# Population   0.017   0.017
# Murder     462.613 845.873

# %%
# import in the data table I downloaded for CA
df_CA = pd.DataFrame()
df_CA = pd.read_excel(
    'table_8_offenses_known_to_law_enforcement_california_by_city_2013.xls', sheet_name='13tbl8ca')

# %%
df_CA.drop([0, 1, 2], inplace=True)

# %%
df_CA.drop('Unnamed: 4', axis=1, inplace=True)

# %%
df_CA.columns = df_CA.loc[3].values
df_CA
# Out:
#                                                   City  Population  \
# 3                                                 City  Population
# 4                                             Adelanto       31165
# 5                                         Agoura Hills       20762
# 6                                              Alameda       76206
# 7                                               Albany       19104
# 8                                             Alhambra       84710
# 9                                          Aliso Viejo       50005
# 10                                             Alturas        2681
# 11                                     American Canyon       20068
# 12                                             Anaheim      345320
# 13                                            Anderson       10098
# 14                                             Antioch      106447
# 15                                        Apple Valley       71159
# 16                                             Arcadia       57855
# 17                                              Arcata       17805
# 18                                       Arroyo Grande       17634
# 19                                             Artesia       16734
# 20                                               Arvin       20390
# 21                                          Atascadero       28938
# 22                                            Atherton        7278
# 23                                             Atwater       28906
# 24                                              Auburn       13779
# 25                                              Avalon        3777
# 26                                              Avenal       14712
# 27                                               Azusa       47754
# 28                                         Bakersfield      361859
# 29                                        Baldwin Park       76745
# 30                                             Banning       30503
# 31                                             Barstow       23144
# 32                                         Bear Valley        5328
# ..                                                 ...         ...
# 438                                              Vista       96712
# 439                                             Walnut       30279
# 440                                       Walnut Creek       66149
# 441                                          Waterford        8590
# 442                                        Watsonville       52076
# 443                                               Weed        2927
# 444                                        West Covina      107867
# 445                                     West Hollywood       34902
# 446                                   Westlake Village        8440
# 447                                        Westminster       91885
# 448                                        Westmorland        2279
# 449                                    West Sacramento       49751
# 450                                          Wheatland        3522
# 451                                           Whittier       86450
# 452                                           Wildomar       33453
# 453                                           Williams        5176
# 454                                            Willits        4832
# 455                                            Willows        6122
# 456                                            Windsor       27249
# 457                                            Winters        6992
# 458                                           Woodlake        7417
# 459                                           Woodland       56523
# 460                                        Yorba Linda       67492
# 461                                         Yountville        2969
# 462                                              Yreka        7639
# 463                                          Yuba City       65133
# 464                                            Yucaipa       52524
# 465                                       Yucca Valley       21214
# 466  1 The figures shown in this column for the off...         NaN
# 467  2 The figures shown in this column for the off...         NaN
#
#      Violent\ncrime  Murder and\nnonnegligent\nmanslaughter  \
# 3    Violent\ncrime  Murder and\nnonnegligent\nmanslaughter
# 4               198                                       2
# 5                19                                       0
# 6               158                                       0
# 7                29                                       0
# 8               163                                       1
# 9                25                                       0
# 10               28                                       1
# 11               54                                       0
# 12             1130                                      11
# 13               63                                       0
# 14              946                                      12
# 15              185                                       3
# 16               77                                       0
# 17               67                                       3
# 18               31                                       0
# 19               63                                       2
# 20              153                                       2
# 21               97                                       1
# 22               10                                       0
# 23              182                                       1
# 24               49                                       0
# 25                4                                       0
# 26               62                                       0
# 27              246                                       2
# 28             1857                                      24
# 29              220                                       5
# 30              129                                       2
# 31              229                                       3
# 32               12                                       0
# ..              ...                                     ...
# 438             445                                       1
# 439              37                                       0
# 440              78                                       0
# 441              29                                       2
# 442             237                                       3
# 443              26                                       0
# 444             231                                       1
# 445             216                                       0
# 446              11                                       0
# 447             283                                       0
# 448               2                                       0
# 449             205                                       1
# 450               0                                       0
# 451             223                                       3
# 452              40                                       0
# 453               5                                       0
# 454              30                                       0
# 455              17                                       0
# 456             105                                       0
# 457               8                                       1
# 458              10                                       1
# 459             272                                       1
# 460              30                                       0
# 461               1                                       0
# 462              49                                       1
# 463             174                                       2
# 464             107                                       0
# 465              86                                       3
# 466             NaN                                     NaN
# 467             NaN                                     NaN
#
#      Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  \
# 3    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault
# 4                             15       52                  129
# 5                              2       10                    7
# 6                             10       85                   63
# 7                              1       24                    4
# 8                              9       81                   72
# 9                              2        4                   19
# 10                             4        2                   21
# 11                             4       31                   19
# 12                            82      437                  600
# 13                             8        9                   46
# 14                            25      352                  557
# 15                            12       58                  112
# 16                             1       37                   39
# 17                             7       15                   42
# 18                             5        4                   22
# 19                             0       28                   33
# 20                             1       16                  134
# 21                            12       24                   60
# 22                             1        1                    8
# 23                             7       22                  152
# 24                             2       13                   34
# 25                             0        2                    2
# 26                             4        6                   52
# 27                             4       36                  204
# 28                            43      708                 1082
# 29                             6       74                  135
# 30                             9       26                   92
# 31                            13       45                  168
# 32                             1        0                   11
# ..                           ...      ...                  ...
# 438                           28      140                  276
# 439                            1       10                   26
# 440                            4       31                   43
# 441                            1        4                   22
# 442                           20       71                  143
# 443                            6        3                   17
# 444                            2      106                  122
# 445                           14       68                  134
# 446                            1        3                    7
# 447                           13       84                  186
# 448                            1        1                    0
# 449                           16       98                   90
# 450                            0        0                    0
# 451                           17       73                  130
# 452                            2       11                   27
# 453                            0        3                    2
# 454                            1        1                   28
# 455                            2        3                   12
# 456                            9        8                   88
# 457                            0        3                    4
# 458                            1        1                    7
# 459                           16       48                  207
# 460                            5        6                   19
# 461                            1        0                    0
# 462                            2        2                   44
# 463                           15       39                  118
# 464                            7       31                   69
# 465                            7       15                   61
# 466                          NaN      NaN                  NaN
# 467                          NaN      NaN                  NaN
#
#      Property\ncrime  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson
# 3    Property\ncrime  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson
# 4                886       381              372                    133     17
# 5                306       109              185                     12      7
# 6               1902       287             1285                    330     17
# 7                557        94              388                     75      7
# 8               1774       344             1196                    234      7
# 9                315        71              224                     20      3
# 10                71        23               46                      2      0
# 11               510        91              387                     32      2
# 12              9611      1412             6518                   1681     35
# 13               721       147              454                    120      5
# 14              4440      1351             1872                   1217     57
# 15              1594       596              775                    223     22
# 16              1518       376             1080                     62      3
# 17               841       147              634                     60     14
# 18               455       137              288                     30      0
# 19               323        91              177                     55      1
# 20               744       323              308                    113     15
# 21               544       119              400                     25      7
# 22               115        34               78                      3      1
# 23              1323       361              804                    158      5
# 24               302        86              190                     26      7
# 25                88        13               57                     18      1
# 26               147        63               67                     17      2
# 27              1098       256              671                    171      6
# 28             16814      4605             9272                   2937    193
# 29              1370       280              727                    363      8
# 30               808       355              323                    130      0
# 31               785       329              354                    102     11
# 32               111        10              101                      0      0
# ..               ...       ...              ...                    ...    ...
# 438             2045       390             1326                    329      6
# 439              463       220              207                     36      0
# 440             2161       364             1634                    163      1
# 441              224        78              104                     42      0
# 442             1308       218              824                    266      9
# 443              110        33               74                      3      0
# 444             3370       615             2254                    501      2
# 445             1435       292             1044                     99      2
# 446              148        40              102                      6      1
# 447             2476       420             1720                    336      8
# 448                6         2                4                      0      0
# 449             1483       380              894                    209      9
# 450               49        16               28                      5      0
# 451             2383       455             1675                    253      4
# 452              536       166              287                     83      1
# 453               67        24               35                      8      1
# 454               61         6               35                     20      2
# 455              179        54              116                      9      0
# 456              269        52              209                      8      4
# 457              115        27               76                     12      2
# 458              134        39               79                     16      0
# 459             1942       510             1238                    194     34
# 460              700       172              482                     46      1
# 461               57        17               34                      6      0
# 462              278        71              193                     14      2
# 463             1980       438             1210                    332     16
# 464              926       262              534                    130     13
# 465              429       141              234                     54      2
# 466              NaN       NaN              NaN                    NaN    NaN
# 467              NaN       NaN              NaN                    NaN    NaN
#
# [465 rows x 12 columns]

# %%
df_CA.drop([3, 466, 467], inplace=True)

# %%
df_CA['Murder'] = df_CA['Murder and\nnonnegligent\nmanslaughter']
df_CA['Property_crime'] = df_CA['Property\ncrime']

# %%
df_CA['Murder'] = df_CA['Murder'].astype(int)
df_CA['Murder'] = df_CA['Murder'].apply(lambda x: (x > 0)*1)

# %%
df_CA['Population'] = df_CA['Population'].astype(int)
df_CA['Property_crime'] = df_CA['Property_crime'].astype(int)

# %%
# Re-fit the model here to CA 
linear_formula = 'Property_crime ~ Population + Murder'

# Fit the model to our data using the formula.
lm_CA = smf.ols(formula=linear_formula, data=df_CA).fit()
print(lm_CA.params)
# print(lm.pvalues)
# print(lm.rsquared)
# print(lm.conf_int())
# Out:
# Intercept    -57.299
# Population     0.024
# Murder       589.797
# dtype: float64

# %%
y_pred = lm.predict(df_CA[['Property_crime', 'Population', 'Murder']])
y = df_CA['Property_crime']
SS_Residual = sum((y - y_pred) ** 2)
SS_Total = sum((y - np.mean(y)) ** 2)
r_squared = 1 - (float(SS_Residual)) / SS_Total
print(r_squared)
print(lm.pvalues)
# Out:
# 0.8032009799627111
# Intercept    0.491
# Population   0.000
# Murder       0.000
# dtype: float64

# %% [markdown]
# We used the linear model that was trained on the NY data set from 2013 and tried it on the 2013 CA data set. This gave us a R^2 value of 0.803.
#
# Next, let's validate our model by comparing how the CA trained linear model will work on the NY data set.
#
# For my model to be trustworthy, I expect the R^2 values to be the same or very similar.

# %%
y_pred = lm_CA.predict(df[['Property_crime', 'Population', 'Murder']])
y = df['Property_crime']
SS_Residual = sum((y - y_pred) ** 2)
SS_Total = sum((y - np.mean(y)) ** 2)
r_squared = 1 - (float(SS_Residual)) / SS_Total
print(r_squared)
print(lm_CA.pvalues)
# Out:
# 0.7998327830081634
# Intercept    0.617
# Population   0.000
# Murder       0.001
# dtype: float64

# %% [markdown]
# Yay! The R^2 value is 0.799, very similar to the 0.803 R^2 value from before. So, I conclude that my model is trustworthy.
#
# Future steps:
# - apply the NY 2013 linear model I made to another year, say 2015, for NY
# - I expect that R^2 values would be closer or improved
#
# - do the fold analysis with 5 groups/folds to see if the components listed at the end give similar values and then I can see whether or not I'm overfitting or not.
